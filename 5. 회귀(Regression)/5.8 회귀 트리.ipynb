# %% [markdown]
# ## 회귀 트리 개요
# - 사이킷런의 결정 트리 및 결정 트리 기반의 앙상블 알고리즘은 분류뿐 아니라 회귀도 가능함(트리가 CART(Classification and Regression Tree)를 기반으로 만들어졌기 때문)
# - CART 회귀 트리는 분류와 유사하게 분할하며, 최종 분할이 완료된 후에 각 분할 영역에 있는 데이터 결정값들의 평균 값으로 학습/예측을 진행

# %% [markdown]
# ## 회귀 트리 프로세스
# ![image.png](attachment:image.png)
# 1. 기준에 따라 트리 분할 진행
# 2. 최종 분할된 영역에 있는 데이터들의 평균값들로 학습/예측 진행

# %% [markdown]
# ## 사이킷런의 회귀 트리 지원
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 회귀 트리의 오버피팅
# - 회귀 트리 역시 복잡한 트리 구조를 가질 경우 오버피팅하기 쉬우므로 트리의 크기와 노드 개수의 제한 등의 방법을 통해 오버피팅을 개선할 수 있음
