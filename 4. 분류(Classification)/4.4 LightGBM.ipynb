# %% [markdown]
# ### LightGBM 개요
# - XGBoost 대비 장점
#     - 더 빠른 학습과 예측 수행 시간
#     - 더 작은 메모리 사용량
#     - 카테고리형 피처의 자동 변환과 최적 분할
#       (원-핫 인코딩 등을 사용하지 않고도 카테고리형 피처를 최적으로 변환하고 이에 따른 노드 분할 수행)
#
#
#
# - LightGBM 트리 분할 방식 : 리프 중심
#
#
# - LightGBM 하이퍼 파라미터
# - ![Alt text](image.png)
# - ![Alt text](image-1.png)
#
# - 파이썬 래퍼와 사이킷런 래퍼 하이퍼 파라미터 비교
# - ![Alt text](image-2.png)

# %% [markdown]
# ### 실습

# %%
import lightgbm
print(lightgbm.__version__)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# 2.3.1

# %% [markdown]
# ##### LightGBM 적용 - 위스콘신 Breast Cancer Prediction

# %%
# breast dataset을 DataFrame 형식으로 고침
from lightgbm import LGBMClassifier

import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")

dataset = load_breast_cancer()

cancer_df = pd.DataFrame(data = dataset.data, columns = dataset.feature_names)
cancer_df["target"] = dataset.target

cancer_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness
# 0        17.99         10.38          122.80     1001.0          0.11840  \
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry
# 0           0.27760          0.3001              0.14710         0.2419  \
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area
# 0                 0.07871  ...          17.33           184.60      2019.0  \
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points
# 0            0.1622             0.6656           0.7119                0.2654  \
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
# 3          0.6638                  0.17300       0
# 4          0.2364                  0.07678       0
#
# [5 rows x 31 columns]

# %%
from sklearn.model_selection import train_test_split
X_features =cancer_df.iloc[:,:-1]
y_label = cancer_df.iloc[:, -1]

# 전체 데이터 중 80%는 학습용 데이터, 20%는 테스트용 데이터 추출
X_train, X_test, y_train, y_test  = train_test_split(X_features, y_label,
                                                     test_size = 0.2, random_state = 156)

# 위에서 만든 X_train, y_train을 다시 쪼개서 90%는 학습과 10%는 검증용 데이터로 분리
X_tr, X_val, y_tr, y_val = train_test_split(X_train, y_train, 
                                            test_size = 0.1, random_state = 156)

# n_estimators = 400
lgbm_wrapper = LGBMClassifier(n_estimators = 400, learning_rate = 0.05)

evals = [(X_tr, y_tr), (X_val, y_val)]
lgbm_wrapper.fit(X_tr, y_tr, early_stopping_rounds =50, eval_metric = "logloss",
                 eval_set = evals, verbose = True)
preds = lgbm_wrapper.predict(X_test)
pred_proba = lgbm_wrapper.predict_proba(X_test)[:,1]  ## 1일 때의 확률 > auc를 구할 땐 tpr을 입력하면 된다.!
# Out:
# [1]	training's binary_logloss: 0.625671	valid_1's binary_logloss: 0.628248
# Training until validation scores don't improve for 50 rounds
# [2]	training's binary_logloss: 0.588173	valid_1's binary_logloss: 0.601106
# [3]	training's binary_logloss: 0.554518	valid_1's binary_logloss: 0.577587
# [4]	training's binary_logloss: 0.523972	valid_1's binary_logloss: 0.556324
# [5]	training's binary_logloss: 0.49615	valid_1's binary_logloss: 0.537407
# [6]	training's binary_logloss: 0.470108	valid_1's binary_logloss: 0.519401
# [7]	training's binary_logloss: 0.446647	valid_1's binary_logloss: 0.502637
# [8]	training's binary_logloss: 0.425055	valid_1's binary_logloss: 0.488311
# [9]	training's binary_logloss: 0.405125	valid_1's binary_logloss: 0.474664
# [10]	training's binary_logloss: 0.386692	valid_1's binary_logloss: 0.462832
# [11]	training's binary_logloss: 0.368104	valid_1's binary_logloss: 0.449734
# [12]	training's binary_logloss: 0.351335	valid_1's binary_logloss: 0.439108
# [13]	training's binary_logloss: 0.336106	valid_1's binary_logloss: 0.428432
# [14]	training's binary_logloss: 0.320995	valid_1's binary_logloss: 0.417674
# [15]	training's binary_logloss: 0.30764	valid_1's binary_logloss: 0.408427
# [16]	training's binary_logloss: 0.29427	valid_1's binary_logloss: 0.399502
# [17]	training's binary_logloss: 0.282032	valid_1's binary_logloss: 0.390328
# [18]	training's binary_logloss: 0.270264	valid_1's binary_logloss: 0.382869
# [19]	training's binary_logloss: 0.259865	valid_1's binary_logloss: 0.376094
# [20]	training's binary_logloss: 0.249393	valid_1's binary_logloss: 0.368958
# [21]	training's binary_logloss: 0.239551	valid_1's binary_logloss: 0.362996
# [22]	training's binary_logloss: 0.230561	valid_1's binary_logloss: 0.356303
# [23]	training's binary_logloss: 0.221717	valid_1's binary_logloss: 0.350425
# [24]	training's binary_logloss: 0.212816	valid_1's binary_logloss: 0.344838
# [25]	training's binary_logloss: 0.204907	valid_1's binary_logloss: 0.339484
# [26]	training's binary_logloss: 0.197838	valid_1's binary_logloss: 0.334541
# [27]	training's binary_logloss: 0.190576	valid_1's binary_logloss: 0.330859
# [28]	training's binary_logloss: 0.183529	valid_1's binary_logloss: 0.326574
# [29]	training's binary_logloss: 0.177072	valid_1's binary_logloss: 0.323247
# [30]	training's binary_logloss: 0.170475	valid_1's binary_logloss: 0.318499
# [31]	training's binary_logloss: 0.164027	valid_1's binary_logloss: 0.314283
# [32]	training's binary_logloss: 0.157348	valid_1's binary_logloss: 0.308474
# [33]	training's binary_logloss: 0.151619	valid_1's binary_logloss: 0.305302
# [34]	training's binary_logloss: 0.146629	valid_1's binary_logloss: 0.300947
# [35]	training's binary_logloss: 0.140405	valid_1's binary_logloss: 0.295637
# [36]	training's binary_logloss: 0.135479	valid_1's binary_logloss: 0.292359
# [37]	training's binary_logloss: 0.130699	valid_1's binary_logloss: 0.290556
# [38]	training's binary_logloss: 0.125331	valid_1's binary_logloss: 0.286204
# [39]	training's binary_logloss: 0.120528	valid_1's binary_logloss: 0.283481
# [40]	training's binary_logloss: 0.116025	valid_1's binary_logloss: 0.28006
# [41]	training's binary_logloss: 0.111562	valid_1's binary_logloss: 0.277637
# [42]	training's binary_logloss: 0.1079	valid_1's binary_logloss: 0.274847
# [43]	training's binary_logloss: 0.103859	valid_1's binary_logloss: 0.272859
# [44]	training's binary_logloss: 0.100138	valid_1's binary_logloss: 0.270262
# [45]	training's binary_logloss: 0.0963746	valid_1's binary_logloss: 0.268073
# [46]	training's binary_logloss: 0.0929572	valid_1's binary_logloss: 0.26671
# [47]	training's binary_logloss: 0.0899324	valid_1's binary_logloss: 0.263785
# [48]	training's binary_logloss: 0.0873289	valid_1's binary_logloss: 0.263664
# [49]	training's binary_logloss: 0.0840183	valid_1's binary_logloss: 0.262173
# [50]	training's binary_logloss: 0.080903	valid_1's binary_logloss: 0.260928
# [51]	training's binary_logloss: 0.0783652	valid_1's binary_logloss: 0.258393
# [52]	training's binary_logloss: 0.075536	valid_1's binary_logloss: 0.257425
# [53]	training's binary_logloss: 0.0728163	valid_1's binary_logloss: 0.259037
# [54]	training's binary_logloss: 0.0702634	valid_1's binary_logloss: 0.258369
# [55]	training's binary_logloss: 0.0676698	valid_1's binary_logloss: 0.258996
# [56]	training's binary_logloss: 0.0654293	valid_1's binary_logloss: 0.259331
# [57]	training's binary_logloss: 0.0632096	valid_1's binary_logloss: 0.259006
# [58]	training's binary_logloss: 0.0612077	valid_1's binary_logloss: 0.259286
# [59]	training's binary_logloss: 0.0591513	valid_1's binary_logloss: 0.257202
# [60]	training's binary_logloss: 0.0572088	valid_1's binary_logloss: 0.257168
# [61]	training's binary_logloss: 0.0551987	valid_1's binary_logloss: 0.258305
# [62]	training's binary_logloss: 0.0534423	valid_1's binary_logloss: 0.258397
# [63]	training's binary_logloss: 0.0516793	valid_1's binary_logloss: 0.2596
# [64]	training's binary_logloss: 0.0500622	valid_1's binary_logloss: 0.26049
# [65]	training's binary_logloss: 0.0485234	valid_1's binary_logloss: 0.260826
# [66]	training's binary_logloss: 0.0470319	valid_1's binary_logloss: 0.260881
# [67]	training's binary_logloss: 0.0456247	valid_1's binary_logloss: 0.260966
# [68]	training's binary_logloss: 0.0441293	valid_1's binary_logloss: 0.262592
# [69]	training's binary_logloss: 0.0428474	valid_1's binary_logloss: 0.262805
# [70]	training's binary_logloss: 0.0413116	valid_1's binary_logloss: 0.265159
# [71]	training's binary_logloss: 0.0398938	valid_1's binary_logloss: 0.263591
# [72]	training's binary_logloss: 0.0385006	valid_1's binary_logloss: 0.266054
# [73]	training's binary_logloss: 0.0373165	valid_1's binary_logloss: 0.264878
# [74]	training's binary_logloss: 0.0360691	valid_1's binary_logloss: 0.263518
# [75]	training's binary_logloss: 0.0347598	valid_1's binary_logloss: 0.263714
# [76]	training's binary_logloss: 0.0334923	valid_1's binary_logloss: 0.261344
# [77]	training's binary_logloss: 0.0323656	valid_1's binary_logloss: 0.263967
# [78]	training's binary_logloss: 0.0312561	valid_1's binary_logloss: 0.26418
# [79]	training's binary_logloss: 0.0302011	valid_1's binary_logloss: 0.266129
# [80]	training's binary_logloss: 0.0291182	valid_1's binary_logloss: 0.263931
# [81]	training's binary_logloss: 0.0281474	valid_1's binary_logloss: 0.264391
# [82]	training's binary_logloss: 0.0272388	valid_1's binary_logloss: 0.267166
# [83]	training's binary_logloss: 0.0262836	valid_1's binary_logloss: 0.265115
# [84]	training's binary_logloss: 0.0254321	valid_1's binary_logloss: 0.267202
# [85]	training's binary_logloss: 0.0245613	valid_1's binary_logloss: 0.265271
# [86]	training's binary_logloss: 0.0237611	valid_1's binary_logloss: 0.265977
# [87]	training's binary_logloss: 0.0230229	valid_1's binary_logloss: 0.268838
# [88]	training's binary_logloss: 0.022253	valid_1's binary_logloss: 0.267025
# [89]	training's binary_logloss: 0.0215231	valid_1's binary_logloss: 0.265913
# [90]	training's binary_logloss: 0.0208833	valid_1's binary_logloss: 0.265612
# [91]	training's binary_logloss: 0.0202353	valid_1's binary_logloss: 0.267831
# [92]	training's binary_logloss: 0.0195726	valid_1's binary_logloss: 0.266689
# [93]	training's binary_logloss: 0.0189295	valid_1's binary_logloss: 0.267654
# [94]	training's binary_logloss: 0.0182642	valid_1's binary_logloss: 0.268718
# [95]	training's binary_logloss: 0.0176871	valid_1's binary_logloss: 0.270958
# [96]	training's binary_logloss: 0.0171794	valid_1's binary_logloss: 0.27016
# [97]	training's binary_logloss: 0.016589	valid_1's binary_logloss: 0.271488
# [98]	training's binary_logloss: 0.0160635	valid_1's binary_logloss: 0.269985
# [99]	training's binary_logloss: 0.0155631	valid_1's binary_logloss: 0.271251
# [100]	training's binary_logloss: 0.0150636	valid_1's binary_logloss: 0.271782
# [101]	training's binary_logloss: 0.0145839	valid_1's binary_logloss: 0.271016
# [102]	training's binary_logloss: 0.0141803	valid_1's binary_logloss: 0.271182
# [103]	training's binary_logloss: 0.0136586	valid_1's binary_logloss: 0.271901
# [104]	training's binary_logloss: 0.0131463	valid_1's binary_logloss: 0.271226
# [105]	training's binary_logloss: 0.0127756	valid_1's binary_logloss: 0.271724
# [106]	training's binary_logloss: 0.0123527	valid_1's binary_logloss: 0.272895
# [107]	training's binary_logloss: 0.0119772	valid_1's binary_logloss: 0.271722
# [108]	training's binary_logloss: 0.0115223	valid_1's binary_logloss: 0.272213
# [109]	training's binary_logloss: 0.0111636	valid_1's binary_logloss: 0.273245
# [110]	training's binary_logloss: 0.0108692	valid_1's binary_logloss: 0.273132
# Early stopping, best iteration is:
# [60]	training's binary_logloss: 0.0572088	valid_1's binary_logloss: 0.257168

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

# %%
def get_clf_eval(y_test, pred=None, pred_proba = None):
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)

    # ROC-AUC추가
    roc_auc = roc_auc_score(y_test, pred_proba)
    print("오차행렬")
    print(confusion)

    # ROC-AUC print 추가
    print("정확도 : {0:.4f}, 정밀도 : {1:.4f}, 재현율 : {2:.4f}, \
          F1 스코어 : {3:.4f}, AUC : {4:.4f}".format(accuracy, precision, recall, f1, roc_auc))

# %%
get_clf_eval(y_test, preds, pred_proba)
# Out:
# 오차행렬
# [[34  3]
#  [ 2 75]]
# 정확도 : 0.9561, 정밀도 : 0.9615, 재현율 : 0.9740,           F1 스코어 : 0.9677, AUC : 0.9888

# %%
# plot_importance()를 이용하여 feature 중요도 시각화
from lightgbm import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize = (10,12))
plot_importance(lgbm_wrapper, ax = ax)
plt.show()
